# %% [markdown]
# # Flight Price Prediction Project:

# %% [markdown]
# Submitted by ANKUSH C Internship Batch : 25

# %% [markdown]
# **STATEMENT: Anyone who has booked a flight ticket knows how unexpectedly the prices vary. The cheapest
# available ticket on a given flight gets more and less expensive over time. This usually happens as
# an attempt to maximize revenue based on**
# - **1. Time of purchase patterns (making sure last-minute purchases are expensive)**
# - **2. Keeping the flight as full as they want it (raising prices on a flight which is filling up in order to reduce sales and hold back inventory for those expensive last-minute expensive purchases)**
#
# **So, you have to work on a project where you collect data of flight fares with other features and
# work to make a model to predict fares of flights.**

# %% [markdown]
# # Importing datasets:

# %%
#importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

import warnings
warnings.filterwarnings('ignore')

# %%
#To print all rows
pd.set_option('display.max_rows',None)

# %%
#importing dataset
df = pd.read_csv("Flight.csv") #Reading csv file
df.head()
# Out:
#    Unnamed: 0   Airline Journey_date From         To  Dtime  Atime  \
# 0           0       NaN          NaN  NaN        NaN    NaN    NaN
# 1           0  Spicejet   24/11/2021  Goa  Ahmedabad  08:15  10:25
# 2           1  Spicejet   24/11/2021  Goa  Ahmedabad  21:05  23:00
# 3           2  Go First   24/11/2021  Goa  Ahmedabad  14:00  18:35
# 4           3  Go First   24/11/2021  Goa  Ahmedabad  13:15  20:25
#
#                   Stops    Price
# 0                   NaN      NaN
# 1              Non stop  ₹ 5,315
# 2              Non stop  ₹ 5,315
# 3  1 stop via Bengaluru  ₹ 5,315
# 4     1 stop via Mumbai  ₹ 5,315

# %% [markdown]
# Since Price is my target and it seems to be continuous feature so this perticular problem is **Regression Problem**.

# %% [markdown]
# # Features Information:

# %% [markdown]
# - Airline: The name of the airline.
# - Journey_date: The date of the journey
# - From: The source from which the service begins.
# - To: The destination where the service ends.
# - Route: The route taken by the flight to reach the destination.
# - D_Time: The time when the journey starts from the source.
# - A_Time: Time of arrival at the destination.
# - Stops: Total stops between the source and destination.
# - Price: The price of the ticket

# %% [markdown]
# # Preprocessing and EDA:

# %%
#Checking shape of my dataset
df.shape
# Out:
# (5204, 9)

# %% [markdown]
# In my dataset i have 5204 rows and 9 columns.

# %%
#Removing Column "Unnamed:0 as it will not affect our core dataset
df.drop('Unnamed: 0',axis=1,inplace=True)
df.head()
# Out:
#     Airline Journey_date From         To  Dtime  Atime                 Stops  \
# 0       NaN          NaN  NaN        NaN    NaN    NaN                   NaN
# 1  Spicejet   24/11/2021  Goa  Ahmedabad  08:15  10:25              Non stop
# 2  Spicejet   24/11/2021  Goa  Ahmedabad  21:05  23:00              Non stop
# 3  Go First   24/11/2021  Goa  Ahmedabad  14:00  18:35  1 stop via Bengaluru
# 4  Go First   24/11/2021  Goa  Ahmedabad  13:15  20:25     1 stop via Mumbai
#
#      Price
# 0      NaN
# 1  ₹ 5,315
# 2  ₹ 5,315
# 3  ₹ 5,315
# 4  ₹ 5,315

# %% [markdown]
# Removing Unnamed: 0 column as it is the index column of csv file.

# %%
#Removing First row as it have only NaN values
df=df.drop([df.index[0]])

# %% [markdown]
# Since i am having all the entries in first row as nan so i have dropped this row.

# %%
#Equalizing Price column
df.Price = df.Price.str.replace('[^0-9.]','').astype('float64')
df.head()
# Out:
#     Airline Journey_date From         To  Dtime  Atime                 Stops  \
# 1  Spicejet   24/11/2021  Goa  Ahmedabad  08:15  10:25              Non stop
# 2  Spicejet   24/11/2021  Goa  Ahmedabad  21:05  23:00              Non stop
# 3  Go First   24/11/2021  Goa  Ahmedabad  14:00  18:35  1 stop via Bengaluru
# 4  Go First   24/11/2021  Goa  Ahmedabad  13:15  20:25     1 stop via Mumbai
# 5  Go First   24/11/2021  Goa  Ahmedabad  06:40  20:25     1 stop via Mumbai
#
#     Price
# 1  5315.0
# 2  5315.0
# 3  5315.0
# 4  5315.0
# 5  5315.0

# %% [markdown]
# I have changed the price column datatype to float.

# %%
#Checking all column names
df.columns
# Out:
# Index(['Airline', 'Journey_date', 'From', 'To', 'Dtime', 'Atime', 'Stops',
#        'Price'],
#       dtype='object')

# %% [markdown]
# Above are the column names of the dataset.

# %%
#Checking the data types of all columns
df.dtypes
# Out:
# Airline          object
# Journey_date     object
# From             object
# To               object
# Dtime            object
# Atime            object
# Stops            object
# Price           float64
# dtype: object

# %% [markdown]
# Except Price all other columns are object type datas.But i have to convert journey_date, d_time and a_time columns from object to datetime type data.

# %%
#Checking the info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5203 entries, 1 to 5203
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Airline       5203 non-null   object
#  1   Journey_date  5203 non-null   object
#  2   From          5203 non-null   object
#  3   To            5203 non-null   object
#  4   Dtime         5203 non-null   object
#  5   Atime         5203 non-null   object
#  6   Stops         5203 non-null   object
#  7   Price         5203 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 365.8+ KB

# %% [markdown]
# - There is no nan values in the dataset.But i have to convert journey_date, d_time and a_time columns from object to datetime type data.

# %%
#Lets check the value count of each column to see if there are any unexpected and unwanted entries present in the column.
for i in df.columns:
        print(df[i].value_counts())
        print('****************************************')
# Out:
# IndiGo                 1767
# Go First               1457
# AirAsia                 512
# Air India               474
# Spicejet                408
# Vistara                 375
# Spicejet, IndiGo         35
# Air India, IndiGo        16
# Spicejet, AirAsia        13
# IndiGo, Air India        12
# IndiGo, Spicejet         11
# AirAsia, IndiGo          11
# IndiGo, Go First         10
# IndiGo, TruJet            9
# Vistara, IndiGo           9
# Spicejet, Air India       8
# Air India, Go First       7
# Vistara, Spicejet         6
# IndiGo, AirAsia           5
# Vistara, Go First         5
# Go First, IndiGo          5
# Air India, AirAsia        5
# Spicejet, Go First        5
# TruJet                    4
# Spicejet, Vistara         4
# TruJet, IndiGo            4
# IndiGo, Vistara           4
# Star Air                  4
# AirAsia, Go First         3
# Air India, Spicejet       3
# Vistara, AirAsia          2
# Go First, AirAsia         2
# Vistara, Air India        2
# Go First, Air India       1
# Spicejet, TruJet          1
# Air India, Vistara        1
# Go First, Spicejet        1
# Vistara, TruJet           1
# AirAsia, TruJet           1
# Name: Airline, dtype: int64
# ****************************************
# 29/11/2021    798
# 30/11/2021    765
# 24/11/2021    761
# 27/11/2021    742
# 25/11/2021    740
# 26/11/2021    718
# 28/11/2021    679
# Name: Journey_date, dtype: int64
# ****************************************
# New Delhi    1368
# Mumbai       1049
# Bengaluru    1001
# Goa           771
# Ahmedabad     634
# Tirupati      380
# Name: From, dtype: int64
# ****************************************
# 07:45     13
# 02:55     13
# 22:05     13
# 21:45     13
# 20:05     13
# 19:00     13
# 10:50     13
# 21:40     13
# 08:30     13
# 15:10     12
# 23:05     12
# 11:35     12
# 18:50     12
# 09:35     12
# 03:20     12
# 22:20     12
# 18:25     11
# 02:10     11
# 00:10     11
# 00:45     11
# 03:15     11
# 12:00     11
# 15:30     11
# 12:20     10
# 11:00     10
# 11:20     10
# 10:25     10
# 12:40     10
# 07:05     10
# 01:05     10
# 03:45     10
# 17:50     10
# 09:40     10
# 02:50      9
# 11:50      9
# 16:20      9
# 06:55      9
# 13:00      9
# 21:20      9
# 16:00      8
# 15:50      8
# 20:00      8
# 05:10      8
# 14:20      8
# 12:35      8
# 21:05      8
# 20:15      7
# 11:05      7
# 02:30      7
# 23:20      7
# 05:25      7
# 16:40      7
# 10:35      7
# 19:50      7
# 22:40      7
# 00:30      7
# 08:45      7
# 14:40      7
# 03:40      6
# 15:00      6
# 17:15      6
# 17:40      6
# 15:25      6
# 18:55      6
# 01:15      6
# 16:05      5
# 16:45      5
# 09:45      5
# 14:35      5
# 13:05      4
# 13:55      4
# 00:15      4
# 14:25      4
# 03:35      4
# 01:40      4
# 12:05      4
# 13:50      4
# 15:35      4
# 09:55      3
# 21:00      3
# 11:55      3
# 15:55      3
# 13:15      3
# 00:25      3
# 21:10      3
# 01:25      3
# 17:20      3
# 08:00      2
# 03:00      2
# 11:40      2
# 00:55      2
# 19:45      2
# 01:10      2
# 18:45      1
# 19:10      1
# 15:20      1
# 06:15      1
# Name: Atime, dtype: int64
# ****************************************
# Non stop                                            2285
# 1 stop via Mumbai                                    573
# 1 stop via Hyderabad                                 570
# 1 stop via Bengaluru                                 296
# 1 stop via New Delhi                                 207
# 1 stop via Ahmedabad                                  97
# 1 stop via Goa                                        86
# 1 stop via Pune                                       78
# 1 stop via Lucknow                                    75
# 1 stop via Ranchi                                     64
# 1 stop via Kolkata                                    61
# 1 stop via Chennai                                    59
# 2 stop via New Delhi,Hyderabad                        43
# 1 stop via Chandigarh                                 41
# 1 stop via Jaipur                                     40
# 1 stop via Kochi                                      40
# 1 stop via Nagpur                                     35
# 2 stop via Hyderabad,New Delhi                        33
# 1 stop via Amritsar                                   32
# 2 stop via Mumbai,Hyderabad                           31
# 2 stop via Mumbai,New Delhi                           25
# 1 stop via Patna                                      24
# 2 stop via Hyderabad,Mumbai                           23
# 2 stop via Bengaluru,Hyderabad                        20
# 2 stop via Hyderabad,Bengaluru                        20
# 1 stop via Surat                                      18
# 1 stop via Guwahati                                   16
# 1 stop via Vadodara                                   15
# 1 stop via Udaipur                                    14
# 2 stop via New Delhi,Mumbai                           14
# 2 stop via Varanasi,Bengaluru                         13
# 2 stop via New Delhi,Chandigarh                       12
# 1 stop via Indore                                     12
# 2 stop via Chandigarh,New Delhi                       11
# 1 stop via Bhavnagar                                  11
# 2 stop via Chandigarh,Ahmedabad                       10
# 2 stop via Ranchi,New Delhi                            9
# 1 stop via Madurai                                     9
# 1 stop via Bagdogra                                    9
# 2 stop via Ranchi,Bengaluru                            8
# 1 stop via Varanasi                                    8
# 2 stop via Ahmedabad,Chandigarh                        7
# 3 stop via Goa,New Delhi,Hyderabad                     7
# 2 stop via Chandigarh,Srinagar                         6
# 2 stop via Bengaluru,Ranchi                            6
# 3 stop via Mumbai,Aurangabad,New Delhi                 6
# 1 stop via Mangalore                                   6
# 1 stop via Srinagar                                    6
# 2 stop via Jammu,Srinagar                              5
# 2 stop via Kochi,Mumbai                                5
# 2 stop via New Delhi,Varanasi                          5
# 3 stop via Chandigarh,New Delhi,Ranchi                 5
# 1 stop via Jammu                                       5
# 3 stop via New Delhi,Aurangabad,Mumbai                 4
# 2 stop via Mumbai,Ranchi                               4
# 1 stop via Jodhpur                                     4
# 2 stop via Chennai,Ranchi                              4
# 2 stop via Hyderabad,Pune                              4
# 1 stop via Vijayawada                                  4
# 1 stop via Kalaburagi                                  4
# 2 stop via Hyderabad,Mysore                            4
# 2 stop via Chennai,Hyderabad                           3
# 2 stop via Nagpur,Pune                                 3
# 3 stop via Leh,Jammu,Srinagar                          3
# 3 stop via Bhubaneswar,New Delhi,Hyderabad             2
# 1 stop via Bhopal                                      2
# 1 stop via Aurangabad                                  2
# 1 stop via Rajkot                                      2
# 2 stop via Vijayawada,Hyderabad                        2
# 1 stop via Tirupati                                    2
# 1 stop via Dehradun                                    2
# 1 stop via Visakhapatnam                               2
# 3 stop via Hyderabad,New Delhi,Mumbai                  2
# 2 stop via Pune,Hyderabad                              2
# 2 stop via Hyderabad,Nanded                            2
# 2 stop via Nanded,Hyderabad                            2
# 1 stop via Mysore                                      2
# 2 stop via Hyderabad,Goa                               2
# 3 stop via Belgaum,Hyderabad,Mumbai                    1
# 2 stop via Srinagar,Chandigarh                         1
# 2 stop via Belgaum,Hyderabad                           1
# 3 stop via Indore,Hyderabad,Mumbai                     1
# 2 stop via Mangalore,Mumbai                            1
# 2 stop via Mumbai,Chandigarh                           1
# 4 stop via Bhubaneswar,Surat,New Delhi,Hyderabad       1
# 3 stop via Hyderabad,New Delhi,Bhopal                  1
# 2 stop via Mysore,Hyderabad                            1
# 2 stop via Hyderabad,Tirupati                          1
# 2 stop via Goa,Hyderabad                               1
# 2 stop via Amritsar,Srinagar                           1
# 2 stop via Hyderabad,Chennai                           1
# 3 stop via Mumbai,New Delhi,Hyderabad                  1
# 3 stop via Hyderabad,New Delhi,Goa                     1
# 3 stop via Hyderabad,New Delhi,Jaipur                  1
# 2 stop via Chennai,Jaipur                              1
# 3 stop via Ahmedabad,New Delhi,Hyderabad               1
# Name: Stops, dtype: int64
# ****************************************
# 7425.0     220
# 5943.0     208
# 5955.0     193
# 5060.0     137
# 4262.0     134
# 5985.0     110
# 5178.0     105
# 5103.0      99
# 7626.0      92
# 5564.0      88
# 7488.0      84
# 4941.0      83
# 4220.0      80
# 7489.0      75
# 7424.0      71
# 5177.0      70
# 5937.0      68
# 5114.0      64
# 5900.0      62
# 5102.0      59
# 5061.0      58
# 7486.0      54
# 6017.0      52
# 5942.0      51
# 5100.0      47
# 5954.0      45
# 4263.0      44
# 7487.0      39
# 4475.0      38
# 4337.0      36
# 5176.0      35
# 7423.0      33
# 5877.0      32
# 7419.0      32
# 4264.0      32
# 5316.0      31
# 5315.0      30
# 6018.0      29
# 7426.0      28
# 13932.0     27
# 5062.0      27
# 5901.0      27
# 5179.0      27
# 5115.0      26
# 3635.0      25
# 5104.0      25
# 5109.0      25
# 5941.0      24
# 5953.0      24
# 7624.0      23
# 3637.0      22
# 5101.0      22
# 4476.0      21
# 4477.0      20
# 4221.0      20
# 4338.0      20
# 4339.0      20
# 6928.0      19
# 7627.0      18
# 7845.0      15
# 4336.0      15
# 5180.0      14
# 9704.0      14
# 7625.0      13
# 8071.0      13
# 7671.0      12
# 4578.0      12
# 8265.0      11
# 8958.0      11
# 10217.0     10
# 7250.0      10
# 6186.0      10
# 4368.0      10
# 5208.0      10
# 8053.0      10
# 3636.0      10
# 8412.0       9
# 5444.0       9
# 9160.0       9
# 8790.0       9
# 6160.0       9
# 7314.0       9
# 14002.0      9
# 10680.0      8
# 4474.0       8
# 9415.0       8
# 9831.0       8
# 5949.0       8
# 4998.0       8
# 5736.0       8
# 8925.0       8
# 5745.0       7
# 6136.0       7
# 6888.0       7
# 6159.0       7
# 5870.0       7
# 14454.0      7
# 6638.0       7
# 6165.0       7
# 5430.0       7
# 10654.0      7
# 4791.0       7
# 5421.0       6
# 5518.0       6
# 4999.0       6
# 8857.0       6
# 6060.0       6
# 8717.0       6
# 7813.0       6
# 8721.0       6
# 10468.0      6
# 6795.0       6
# 4326.0       6
# 3808.0       6
# 6781.0       6
# 9362.0       5
# 8085.0       5
# 8994.0       5
# 8258.0       5
# 16029.0      5
# 5773.0       5
# 7478.0       5
# 6704.0       5
# 5996.0       5
# 9728.0       5
# 6353.0       5
# 8720.0       5
# 8055.0       5
# 5975.0       5
# 12633.0      5
# 7173.0       5
# 8883.0       5
# 8057.0       5
# 6281.0       5
# 3952.0       5
# 6008.0       5
# 5690.0       4
# 8841.0       4
# 6690.0       4
# 11928.0      4
# 8918.0       4
# 7143.0       4
# 3429.0       4
# 9834.0       4
# 3498.0       4
# 10635.0      4
# 7205.0       4
# 6051.0       4
# 6480.0       4
# 7593.0       4
# 7635.0       4
# 5059.0       4
# 6258.0       4
# 10412.0      4
# 8671.0       4
# 6006.0       4
# 5376.0       4
# 11501.0      4
# 5733.0       4
# 5976.0       4
# 6848.0       4
# 4536.0       4
# 5664.0       4
# 8988.0       4
# 8781.0       4
# 5732.0       4
# 6365.0       4
# 10250.0      4
# 8991.0       4
# 11294.0      3
# 5220.0       3
# 6426.0       3
# 6270.0       3
# 6914.0       3
# 6333.0       3
# 18337.0      3
# 13579.0      3
# 4269.0       3
# 4427.0       3
# 5586.0       3
# 6375.0       3
# 8272.0       3
# 10797.0      3
# 7422.0       3
# 8011.0       3
# 9962.0       3
# 10537.0      3
# 4118.0       3
# 6584.0       3
# 5666.0       3
# 6920.0       3
# 9956.0       3
# 10629.0      3
# 3849.0       3
# 6626.0       3
# 20287.0      3
# 9149.0       3
# 8884.0       3
# 8454.0       3
# 7970.0       3
# 10008.0      3
# 10674.0      3
# 7732.0       3
# 9727.0       3
# 8885.0       3
# 7622.0       3
# 14580.0      3
# 5312.0       3
# 8464.0       3
# 13086.0      3
# 10532.0      3
# 8263.0       3
# 9207.0       3
# 9431.0       3
# 9788.0       3
# 6782.0       3
# 4222.0       3
# 4736.0       3
# 10418.0      3
# 6123.0       3
# 8719.0       3
# 7731.0       3
# 8513.0       3
# 8757.0       3
# 8108.0       3
# 5270.0       3
# 4788.0       3
# 10858.0      3
# 7308.0       3
# 10470.0      3
# 4969.0       3
# 8678.0       3
# 6643.0       3
# 9832.0       3
# 8509.0       3
# 8065.0       3
# 10323.0      3
# 11888.0      3
# 5019.0       3
# 4653.0       3
# 5156.0       3
# 10219.0      3
# 8895.0       3
# 10041.0      3
# 5692.0       3
# 12289.0      3
# 8722.0       3
# 5566.0       3
# 10340.0      3
# 12141.0      3
# 9128.0       3
# 7876.0       3
# 11406.0      3
# 8497.0       3
# 19151.0      2
# 5391.0       2
# 8612.0       2
# 5481.0       2
# 10995.0      2
# 9156.0       2
# 4842.0       2
# 8748.0       2
# 6326.0       2
# 8133.0       2
# 15546.0      2
# 8789.0       2
# 8465.0       2
# 8013.0       2
# 3795.0       2
# 10599.0      2
# 4897.0       2
# 5209.0       2
# 5418.0       2
# 7019.0       2
# 7981.0       2
# 7941.0       2
# 11310.0      2
# 10243.0      2
# 8139.0       2
# 7543.0       2
# 13213.0      2
# 5357.0       2
# 6575.0       2
# 4372.0       2
# 4965.0       2
# 10218.0      2
# 4687.0       2
# 4371.0       2
# 7539.0       2
# 9314.0       2
# 11068.0      2
# 9378.0       2
# 8990.0       2
# 11100.0      2
# 6597.0       2
# 9302.0       2
# 9379.0       2
# 6686.0       2
# 10171.0      2
# 7749.0       2
# 8463.0       2
# 10507.0      2
# 9589.0       2
# 8256.0       2
# 11599.0      2
# 9771.0       2
# 7894.0       2
# 9665.0       2
# 5001.0       2
# 7698.0       2
# 9494.0       2
# 8484.0       2
# 13769.0      2
# 9619.0       2
# 7677.0       2
# 9694.0       2
# 10095.0      2
# 6023.0       2
# 6585.0       2
# 6533.0       2
# 4904.0       2
# 7740.0       2
# 8328.0       2
# 7633.0       2
# 16455.0      2
# 11250.0      2
# 12082.0      2
# 9150.0       2
# 8970.0       2
# 8571.0       2
# 6111.0       2
# 11048.0      2
# 12081.0      2
# 8306.0       2
# 15640.0      2
# 5956.0       2
# 7819.0       2
# 7583.0       2
# 7991.0       2
# 7270.0       2
# 7942.0       2
# 9255.0       2
# 8179.0       2
# 5283.0       2
# 5890.0       2
# 7601.0       2
# 9578.0       2
# 5999.0       2
# 10365.0      2
# 12638.0      2
# 9015.0       2
# 9305.0       2
# 8946.0       2
# 5746.0       2
# 5471.0       2
# 10255.0      2
# 10353.0      2
# 9903.0       2
# 12570.0      2
# 7530.0       2
# 7241.0       2
# 12279.0      2
# 8483.0       2
# 11091.0      2
# 9245.0       2
# 7905.0       2
# 6479.0       2
# 4486.0       2
# 5401.0       2
# 11415.0      2
# 3741.0       2
# 8329.0       2
# 6936.0       2
# 9298.0       2
# 12003.0      2
# 7110.0       2
# 10882.0      2
# 6891.0       2
# 8260.0       2
# 8685.0       2
# 9620.0       2
# 5838.0       2
# 13664.0      2
# 12173.0      2
# 12669.0      1
# 23640.0      1
# 10677.0      1
# 7210.0       1
# 11196.0      1
# 9297.0       1
# 9427.0       1
# 10349.0      1
# 12411.0      1
# 4265.0       1
# 9758.0       1
# 10291.0      1
# 5627.0       1
# 9786.0       1
# 13505.0      1
# 8630.0       1
# 10577.0      1
# 5419.0       1
# 8538.0       1
# 8683.0       1
# 5523.0       1
# 6478.0       1
# 14874.0      1
# 16340.0      1
# 6473.0       1
# 13188.0      1
# 15850.0      1
# 11512.0      1
# 14295.0      1
# 9990.0       1
# 11269.0      1
# 8482.0       1
# 8496.0       1
# 6315.0       1
# 12599.0      1
# 5679.0       1
# 31147.0      1
# 15294.0      1
# 10209.0      1
# 6836.0       1
# 9045.0       1
# 9455.0       1
# 8123.0       1
# 13821.0      1
# 7189.0       1
# 9635.0       1
# 8369.0       1
# 8527.0       1
# 10490.0      1
# 6155.0       1
# 9757.0       1
# 9517.0       1
# 9785.0       1
# 7204.0       1
# 9308.0       1
# 19599.0      1
# 5685.0       1
# 13041.0      1
# 12396.0      1
# 16013.0      1
# 10921.0      1
# 10416.0      1
# 9655.0       1
# 8159.0       1
# 4845.0       1
# 11268.0      1
# 12741.0      1
# 10607.0      1
# 10964.0      1
# 8684.0       1
# 12109.0      1
# 14922.0      1
# 8042.0       1
# 4472.0       1
# 10103.0      1
# 10829.0      1
# 9526.0       1
# 8105.0       1
# 7600.0       1
# 6317.0       1
# 6334.0       1
# 9154.0       1
# 10313.0      1
# 8094.0       1
# 5580.0       1
# 10827.0      1
# 9652.0       1
# 6363.0       1
# 6753.0       1
# 12873.0      1
# 7144.0       1
# 12288.0      1
# Name: Price, dtype: int64
# ****************************************

# %% [markdown]
# Above are the value counts of each column.In Airline and Stops column we have to use grouping to get better understanding on the feature.

# %%
#Grouping Airlines column for multiple airlines
df["Airline"].replace(("Spicejet, IndiGo","Air India, IndiGo","Spicejet, AirAsia","IndiGo, Air India","IndiGo, Spicejet","AirAsia, IndiGo","IndiGo, Go First","IndiGo, TruJet","Vistara, IndiGo","Spicejet, Air India","Air India, Go First","Vistara, Spicejet","Spicejet, Go First","Go First, IndiGo","IndiGo, AirAsia","Air India, AirAsia","Vistara, Go First","TruJet, IndiGo","Spicejet, Vistara","IndiGo, Vistara","Air India, Spicejet","AirAsia, Go First","Vistara, AirAsia","Vistara, Air India","Go First, AirAsia","Spicejet, TruJet","Vistara, TruJet","AirAsia, TruJet","Go First, Air India","Go First, Spicejet","Air India, Vistara"),"Multiple Airlines",inplace=True)

# %%
#Checking the value counts of Airline column
df.Airline.value_counts()
# Out:
# IndiGo               1767
# Go First             1457
# AirAsia               512
# Air India             474
# Spicejet              408
# Vistara               375
# Multiple Airlines     202
# TruJet                  4
# Star Air                4
# Name: Airline, dtype: int64

# %%
#Grouping Stops column 
df["Stops"].replace(("1 stop via Mumbai","1 stop via Hyderabad","1 stop via Bengaluru","1 stop via New Delhi","1 stop via Ahmedabad","1 stop via Goa","1 stop via Pune","1 stop via Lucknow","1 stop via Ranchi","1 stop via Kolkata","1 stop via Chennai","1 stop via Chandigarh","1 stop via Kochi","1 stop via Jaipur","1 stop via Nagpur","1 stop via Amritsar","1 stop via Patna","1 stop via Surat","1 stop via Guwahati","1 stop via Vadodara","1 stop via Udaipur","1 stop via Indore","1 stop via Bhavnagar","1 stop via Madurai","1 stop via Bagdogra","1 stop via Varanasi","1 stop via Srinagar","1 stop via Mangalore","1 stop via Jammu","1 stop via Vijayawada","1 stop via Jodhpur","1 stop via Kalaburagi","1 stop via Aurangabad","1 stop via Rajkot","1 stop via Mysore","1 stop via Bhopal","1 stop via Tirupati","1 stop via Dehradun","1 stop via Visakhapatnam"),"1 Stop",inplace=True)

# %%
#Grouping Stops column
df["Stops"].replace(("2 stop via New Delhi,Hyderabad","2 stop via Hyderabad,New Delhi","2 stop via Mumbai,Hyderabad","2 stop via Mumbai,New Delhi","2 stop via Hyderabad,Mumbai","2 stop via Bengaluru,Hyderabad","2 stop via Hyderabad,Bengaluru","2 stop via New Delhi,Mumbai","2 stop via Varanasi,Bengaluru","2 stop via New Delhi,Chandigarh","2 stop via Chandigarh,New Delhi","2 stop via Chandigarh,Ahmedabad","2 stop via Ranchi,New Delhi","2 stop via Ranchi,Bengaluru","2 stop via Ahmedabad,Chandigarh","2 stop via Chandigarh,Srinagar","2 stop via Bengaluru,Ranchi","2 stop via Jammu,Srinagar","2 stop via Kochi,Mumbai","2 stop via New Delhi,Varanasi","2 stop via Hyderabad,Mysore","2 stop via Mumbai,Ranchi","2 stop via Chennai,Ranchi","2 stop via Hyderabad,Pune","2 stop via Nagpur,Pune","2 stop via Chennai,Hyderabad","2 stop via Pune,Hyderabad","2 stop via Hyderabad,Nanded","2 stop via Vijayawada,Hyderabad","2 stop via Hyderabad,Goa","2 stop via Nanded,Hyderabad","2 stop via Mumbai,Chandigarh","2 stop via Belgaum,Hyderabad","2 stop via Chennai,Jaipur","2 stop via Hyderabad,Chennai","2 stop via Hyderabad,Tirupati","2 stop via Srinagar,Chandigarh","2 stop via Mangalore,Mumbai","2 stop via Amritsar,Srinagar","2 stop via Goa,Hyderabad","2 stop via Mysore,Hyderabad"),"2 Stops",inplace=True)

# %%
#Grouping Stops column
df["Stops"].replace(("3 stop via Goa,New Delhi,Hyderabad","3 stop via Mumbai,Aurangabad,New Delhi","3 stop via Chandigarh,New Delhi,Ranchi","3 stop via New Delhi,Aurangabad,Mumbai","3 stop via Leh,Jammu,Srinagar","3 stop via Bhubaneswar,New Delhi,Hyderabad","3 stop via Hyderabad,New Delhi,Mumbai","3 stop via Indore,Hyderabad,Mumbai","3 stop via Hyderabad,New Delhi,Jaipur","3 stop via Hyderabad,New Delhi,Goa","3 stop via Ahmedabad,New Delhi,Hyderabad","3 stop via Belgaum,Hyderabad,Mumbai","3 stop via Hyderabad,New Delhi,Bhopal","3 stop via Mumbai,New Delhi,Hyderabad"),"3 Stops",inplace=True)

# %%
#Grouping Stops column
df["Stops"].replace(("4 stop via Bhubaneswar,Surat,New Delhi,Hyderabad"),"4 Stops",inplace=True)

# %%
#Checking the value counts of Stops column
df.Stops.value_counts()
# Out:
# 1 Stop      2533
# Non stop    2285
# 2 Stops      348
# 3 Stops       36
# 4 Stops        1
# Name: Stops, dtype: int64

# %%
#Let me assign values for Stops column
df.replace({"Non stop": 0,"1 Stop": 1,"2 Stops": 2,"3 Stops": 3,"4 Stops": 4},inplace = True)

# %%
#Checking the value counts of Stops column again
df.Stops.value_counts()
# Out:
# 1    2533
# 0    2285
# 2     348
# 3      36
# 4       1
# Name: Stops, dtype: int64

# %% [markdown]
# Now Stops column is set for our analysis.

# %%
#Checking null values in Dataset
print("Empty cells in Dataset is ",df.isna().values.any())
print("\nColumnwise Empty cell analysis\n")
print(df.isna().sum())
# Out:
# Empty cells in Dataset is  False
#
# Columnwise Empty cell analysis
#
# Airline         0
# Journey_date    0
# From            0
# To              0
# Dtime           0
# Atime           0
# Stops           0
# Price           0
# dtype: int64

# %% [markdown]
# I don't find any nan values in the dataset.

# %%
#Visualizeing null values
plt.figure(figsize=[12,4])
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# By visualization we can clearly say that there is no null values in the dataset.

# %%
#Checking for empty observations
df.loc[df['Price'] == " "]
# Out:
# Empty DataFrame
# Columns: [Airline, Journey_date, From, To, Dtime, Atime, Stops, Price]
# Index: []

# %% [markdown]
# There is no empty observations in my target column.

# %% [markdown]
# # Feature Extraction:

# %%
#Converting object data type to datetime in Journey_date column 
df['Journey_date'] =  pd.to_datetime(df['Journey_date'])

# %%
#Extracting Journey year,month and day from Journey_date

#Extracting year
df["Journey_year"]=pd.to_datetime(df.Journey_date, format="%Y/%m/%d").dt.year

#Extracting month
df["Journey_mon"]=pd.to_datetime(df.Journey_date, format="%Y/%m/%d").dt.month

#Extracting day
df["Journey_day"]=pd.to_datetime(df.Journey_date, format="%Y/%m/%d").dt.day

# %%
#Checking valuecount of Journey_year column
df.Journey_year.value_counts()
# Out:
# 2021    5203
# Name: Journey_year, dtype: int64

# %% [markdown]
# Since all the entries in Journey_year column are same let's drop as it will not help in our core analysis.

# %%
#Droping Journey_year column
df = df.drop(["Journey_year"],axis=1)

# %%
#Checking valuecount of Journey_mon column
df.Journey_mon.value_counts()
# Out:
# 11    5203
# Name: Journey_mon, dtype: int64

# %% [markdown]
# Since all the entries in Journey_mon column are same let's drop as it will not help in our core analysis.

# %%
#Droping Journey_mon column
df = df.drop(["Journey_mon"],axis=1)

# %%
#Checking valuecount of Journey_year column
df.Journey_day.value_counts()
# Out:
# 29    798
# 30    765
# 24    761
# 27    742
# 25    740
# 26    718
# 28    679
# Name: Journey_day, dtype: int64

# %% [markdown]
# Now Journey_day is ready for our analysis.

# %%
#Droping Journey_date column
df = df.drop(["Journey_date"],axis=1)

# %% [markdown]
# Dropping Journey_date column after extracting requered information.

# %%
#Converting object data type to datetime 
df['Dtime'] =  pd.to_datetime(df['Dtime'])
df['Atime'] =  pd.to_datetime(df['Atime'])

# %%
#Checking the data types of all columns again
df.dtypes
# Out:
# Airline                object
# From                   object
# To                     object
# Dtime          datetime64[ns]
# Atime          datetime64[ns]
# Stops                   int64
# Price                 float64
# Journey_day             int64
# dtype: object

# %% [markdown]
# The data type has changed now.

# %%
#Extracting hours and minutes from Dtime

#Extracting Hours
df["Dhour"]=pd.to_datetime(df["Dtime"]).dt.hour

#Extracting Hours
df["DMin"]=pd.to_datetime(df["Dtime"]).dt.minute

# %%
#Droping Dep_Time column after extraction
df = df.drop(["Dtime"],axis=1)

# %%
#Extracting hours and minutes from Arrival_Time

#Extracting Hours
df["AHour"]=pd.to_datetime(df["Atime"]).dt.hour

#Extracting Hours
df["AMin"]=pd.to_datetime(df["Atime"]).dt.minute

# %%
#Droping Arrival_Time column after extraction
df = df.drop(["Atime"],axis=1)

# %%
#Checking the data types of all columns again
df.dtypes
# Out:
# Airline         object
# From            object
# To              object
# Stops            int64
# Price          float64
# Journey_day      int64
# Dhour            int64
# DMin             int64
# AHour            int64
# AMin             int64
# dtype: object

# %% [markdown]
# This is the datatypes after extraction and preprocessing.

# %%
#Checking description of data set
df.describe()
# Out:
#              Stops         Price  Journey_day        Dhour         DMin  \
# count  5203.000000   5203.000000  5203.000000  5203.000000  5203.000000
# mean      0.642130   6846.891601    27.017106    12.517970    24.955795
# std       0.638332   2509.772290     2.022627     6.335777    18.153357
# min       0.000000   3429.000000    24.000000     0.000000     0.000000
# 25%       0.000000   5114.000000    25.000000     7.000000    10.000000
# 50%       1.000000   5955.000000    27.000000    12.000000    25.000000
# 75%       1.000000   7624.000000    29.000000    18.000000    40.000000
# max       4.000000  31147.000000    30.000000    23.000000    55.000000
#
#              AHour         AMin
# count  5203.000000  5203.000000
# mean     13.152989    27.685950
# std       6.832345    16.896847
# min       0.000000     0.000000
# 25%       8.000000    10.000000
# 50%      13.000000    30.000000
# 75%      19.000000    40.000000
# max      23.000000    55.000000

# %% [markdown]
# Above is the statistics about the dataset.The mean and the 2nd quantile values are almost same so there is no extreme outliers in the dataset.

# %% [markdown]
# # Visualization:

# %% [markdown]
# # Univariate Analysis:

# %%
# checking for categorical columns
categorical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_columns.append(i)
print(categorical_columns)
# Out:
# ['Airline', 'From', 'To']

# %% [markdown]
# Above are the categorical columns in the data set.

# %%
# Now checking for numerical columns
numerical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_columns.append(i)
print(numerical_columns)
# Out:
# ['Stops', 'Price', 'Journey_day', 'Dhour', 'DMin', 'AHour', 'AMin']

# %% [markdown]
# Above are the numerical columns in the data set.

# %% [markdown]
# # Univariate analysis for numerical columns:

# %%
#Distribution plot for all numerical columns
plt.figure(figsize = (30,16))
plotnumber = 1
for column in df[numerical_columns]:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 25)
        plt.ylabel('Density',fontsize = 25)
        plt.xticks(fontsize=20)  
        plt.yticks(fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# There is no skewness in any of the numerical columns.

# %% [markdown]
# # Univariate Analysis for categorical columns:

# %%
#Bar plot for all Categorical columns
plt.figure(figsize = (30,10))
plotnumber = 1
for column in df[categorical_columns]:
    if plotnumber <=3:
        ax = plt.subplot(1,3,plotnumber)
        sns.countplot(df[column])
        plt.xlabel(column,fontsize = 25)
        plt.ylabel('Count',fontsize = 25)
        plt.xticks(rotation=90,fontsize=20)  
        plt.yticks(fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# - Indigo has maximum count which means most of the passengers preferred Indigo for there travelling.
# - New Delhi has maximum count for source which means maximum passengers are choosing New Delhi as there source.
# - New Delhi has maximum count for Destination which means maximum passengers are choosing New Delhi as there Destination.

# %% [markdown]
# # Bivariate Analysis:

# %%
col=['Stops', 'Journey_day', 'Dhour', 'DMin', 'AHour', 'AMin']

# %%
#stripplot for numerical columns
plt.figure(figsize=(40,40))
for i in range(len(col)):
    plt.subplot(4,2,i+1)
    sns.stripplot(x=df[col[i]] , y=df['Price'])
    plt.title(f"Price VS {col[i]}",fontsize=40)
    plt.xticks(fontsize=25)  
    plt.yticks(fontsize=25)
    plt.xlabel(col[i],fontsize = 30)
    plt.ylabel('Price',fontsize = 30)
    plt.tight_layout()

# %% [markdown]
# **Observations:**
# - Flights with 2 stops costs more price compared to other flights.
# - In all the dates the price is almost same.
# - At 2PM departure time of every day the flight Prices are high so it looks good to book flights rather than this departure time.
# - And Departure minute has less relation with target Price.
# - At 7AM to 1PM Arrival time of every day the flight Prices are high so it looks good to book flights rather than this arrival time.
# - And Arrival minute has less relation with target Price.

# %%
#Bar plot for all categorical columns
plt.figure(figsize=(20,20))
for i in range(len(categorical_columns)):
    plt.subplot(3,2,i+1)
    sns.barplot(y=df['Price'],x=df[categorical_columns[i]])
    plt.title(f"Price VS {categorical_columns[i]}",fontsize=25)
    plt.xticks(rotation=90,fontsize=15)  
    plt.yticks(rotation=0,fontsize=15)
    plt.xlabel(categorical_columns[i],fontsize = 20)
    plt.ylabel('Price',fontsize = 20)
    plt.tight_layout()

# %% [markdown]
# **Observations:**
# - For Multiple Airlines the Price is high compared to other Airlines.
# - Taking Tirupati as Source costs highest Price Compared to other Source points.
# - Taking Tirupati as Destination costs highest Price Compared to other Destination points.

# %% [markdown]
# # Multivariate Analysis:

# %%
#pair ploting for df
sns.pairplot(df,hue="Price")

# %% [markdown]
# Above are the pair plots of each pair of features.

# %% [markdown]
# # Checking for outliers:

# %%
# Identifying the outliers using boxplot

plt.figure(figsize=(30,15),facecolor='white')
plotnumber=1
for column in numerical_columns:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[column],color='gold')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# There are outliers in
# - Stops
# - Price
#
# Since Price is my target i should not remove outliers from this column.And Stops is a categorical column So i should not remove outliers here also.

# %% [markdown]
# # Checking for skewness:

# %%
#Checking for skewness
df.skew()
# Out:
# Stops          0.659618
# Price          2.166729
# Journey_day   -0.012994
# Dhour          0.015868
# DMin           0.107587
# AHour         -0.250471
# AMin          -0.027810
# dtype: float64

# %% [markdown]
# There is skewness in Stops and Price.Since Price is my target i should not remove skewness in that column since i don't want my target to get manupulated. And Stops is categorical column so i should not remove skewness here also.

# %% [markdown]
# # Label Encoding:

# %%
# Separating categorical columns in df_1
cat_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        cat_col.append(i)
print(cat_col)
# Out:
# ['Airline', 'From', 'To']

# %% [markdown]
# Above are the list of categorical columns in df.

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df[cat_col]= df[cat_col].apply(LE.fit_transform)

# %%
df.head()
# Out:
#    Airline  From  To  Stops   Price  Journey_day  Dhour  DMin  AHour  AMin
# 1        5     2   0      0  5315.0           24      8    15     10    25
# 2        5     2   0      0  5315.0           24     21     5     23     0
# 3        2     2   0      1  5315.0           24     14     0     18    35
# 4        2     2   0      1  5315.0           24     13    15     20    25
# 5        2     2   0      1  5315.0           24      6    40     20    25

# %% [markdown]
# Using label encoder i have encoded the categorical columns.

# %% [markdown]
# # Checking correlation using heat map:

# %%
cor=df.corr()

# %% [markdown]
# Checking correlation.

# %%
cor
# Out:
#               Airline      From        To     Stops     Price  Journey_day  \
# Airline      1.000000  0.068539  0.025962 -0.258423 -0.039616     0.002134
# From         0.068539  1.000000 -0.236589  0.051194  0.200997    -0.013849
# To           0.025962 -0.236589  1.000000  0.045298  0.086125     0.019675
# Stops       -0.258423  0.051194  0.045298  1.000000  0.372672    -0.006573
# Price       -0.039616  0.200997  0.086125  0.372672  1.000000    -0.041830
# Journey_day  0.002134 -0.013849  0.019675 -0.006573 -0.041830     1.000000
# Dhour       -0.044661 -0.048770 -0.075469 -0.059203 -0.018444    -0.002312
# DMin         0.184257 -0.051594  0.012290 -0.084063 -0.049541    -0.010398
# AHour        0.036837  0.068208  0.022515  0.042220  0.009203     0.010633
# AMin        -0.049054 -0.024735 -0.015172  0.028093  0.004333     0.026470
#
#                 Dhour      DMin     AHour      AMin
# Airline     -0.044661  0.184257  0.036837 -0.049054
# From        -0.048770 -0.051594  0.068208 -0.024735
# To          -0.075469  0.012290  0.022515 -0.015172
# Stops       -0.059203 -0.084063  0.042220  0.028093
# Price       -0.018444 -0.049541  0.009203  0.004333
# Journey_day -0.002312 -0.010398  0.010633  0.026470
# Dhour        1.000000  0.016069  0.112732  0.017932
# DMin         0.016069  1.000000 -0.008772 -0.077638
# AHour        0.112732 -0.008772  1.000000 -0.021302
# AMin         0.017932 -0.077638 -0.021302  1.000000

# %% [markdown]
# Above are the correlations of all the pair of features.To get better visualization on the correlation of features,let me plot it using heat map.

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.1g', annot = True, linecolor="black",annot_kws={'size':10},cmap="coolwarm")
plt.yticks(rotation=0);

# %% [markdown]
# - There is no multicolinearity issue in any features.
# - AMin is very less correlated with target.

# %%
plt.figure(figsize=(15,6))
df.corr()['Price'].sort_values(ascending=False).drop(['Price']).plot(kind='bar',color='g')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# AMin is very less correlated with target.

# %% [markdown]
# # Separating features and label in train dataset:

# %%
x = df.drop("Price",axis=1)
y = df["Price"]

# %% [markdown]
# I have separated my target and independent columns.

# %% [markdown]
# # Scaling the data using standard scaler:

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# %% [markdown]
# I have scaled my data using standard scaler.

# %%
X.head()
# Out:
#     Airline      From        To     Stops  Journey_day     Dhour      DMin  \
# 0  1.148553 -0.334434 -1.581111 -1.006046     -1.49182 -0.713157 -0.548480
# 1  1.148553 -0.334434 -1.581111 -1.006046     -1.49182  1.338880 -1.099395
# 2 -0.425715 -0.334434 -1.581111  0.560688     -1.49182  0.233937 -1.374853
# 3 -0.425715 -0.334434 -1.581111  0.560688     -1.49182  0.076088 -0.548480
# 4 -0.425715 -0.334434 -1.581111  0.560688     -1.49182 -1.028855  0.828808
#
#       AHour      AMin
# 0 -0.461524 -0.158977
# 1  1.441373 -1.638685
# 2  0.709490  0.432906
# 3  1.002243 -0.158977
# 4  1.002243 -0.158977

# %% [markdown]
# This is the data of independent variables after scaling.

# %% [markdown]
# # Checking for multicolinearity issue using VIF:

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#    vif_Features     Features
# 0      1.124176      Airline
# 1      1.088967         From
# 2      1.077445           To
# 3      1.092173        Stops
# 4      1.001492  Journey_day
# 5      1.033146        Dhour
# 6      1.046837         DMin
# 7      1.026260        AHour
# 8      1.010120         AMin

# %% [markdown]
# There is no multicolinearity issue in this dataset.

# %% [markdown]
# # Finding Best Random State and Accuracy:

# %%
#importing necessary libraries
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestRegressor
maxAccu=0
maxRS=0
for i in range(1,200):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.30, random_state =i)
    mod = RandomForestRegressor()
    mod.fit(X_train, y_train)
    pred = mod.predict(X_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.8082013536789746  on Random_state  44

# %% [markdown]
# I got the best accuracy and random state.

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=maxRS)

# %% [markdown]
# Created train test split.

# %% [markdown]
# # Regression Algorithms:

# %%
#importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import SGDRegressor
from xgboost import XGBRegressor
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor
from sklearn import metrics

# %% [markdown]
# # i) RandomForestRegressor:

# %%
RFR=RandomForestRegressor()
RFR.fit(X_train,y_train)
pred=RFR.predict(X_test)
R2_score = r2_score(y_test,pred)*100
print('R2_score:',R2_score)
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 81.05921939883352
# mean_squared_error: 1178818.6868681058
# mean_absolute_error: 582.8659834965376
# root_mean_squared_error: 1085.7341695222206

# %% [markdown]
# RFR is giving me 81.06% r2_score.

# %% [markdown]
# # ii) XGB Regressor:

# %%
XGB=XGBRegressor()
XGB.fit(X_train,y_train)
pred=XGB.predict(X_test)
R2_score = r2_score(y_test,pred)*100
print('R2_score:',R2_score)
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 79.56952342348205
# mean_squared_error: 1271532.9994655694
# mean_absolute_error: 678.8862794219951
# root_mean_squared_error: 1127.6227203571102

# %% [markdown]
# XGB is giving me 79.57% r2_score.

# %% [markdown]
# # iii) ExtraTreeRegressor:

# %%
ETR=ExtraTreesRegressor()
ETR.fit(X_train,y_train)
pred=ETR.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.811783877185204
# mean_squared_error: 1171401.9998219074
# mean_absolute_error: 535.5772720478325
# root_mean_squared_error: 1082.3132632569498

# %% [markdown]
# ETR is giving me 81.18% r2_score.

# %% [markdown]
# # iv) Gradient Boosting Regressor:

# %%
GBR=GradientBoostingRegressor()
GBR.fit(X_train,y_train)
pred=GBR.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.6569134340645822
# mean_squared_error: 2135270.259733484
# mean_absolute_error: 952.091629491256
# root_mean_squared_error: 1461.2563976706772

# %% [markdown]
# GBR is giving me 65.69% r2_score.

# %% [markdown]
# # v) DecisionTreeRegressor:

# %%
DTR=DecisionTreeRegressor()
DTR.fit(X_train,y_train)
pred=DTR.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.6459859162056638
# mean_squared_error: 2203279.92905189
# mean_absolute_error: 647.523062139654
# root_mean_squared_error: 1484.34494948172

# %% [markdown]
# DTR is giving me 64.60% r2_score.

# %% [markdown]
# # vi) KNN:

# %%
knn=KNN()
knn.fit(X_train,y_train)
pred=knn.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.532582749003129
# mean_squared_error: 2909068.013837284
# mean_absolute_error: 1092.0563741191545
# root_mean_squared_error: 1705.599019065526

# %% [markdown]
# KNN is giving me 53.26% r2_score.

# %% [markdown]
# # vii) Bagging Regressor:

# %%
BG=BaggingRegressor()
BG.fit(X_train,y_train)
pred=BG.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.7897988903795836
# mean_squared_error: 1308230.1159525483
# mean_absolute_error: 606.6656438180654
# root_mean_squared_error: 1143.7788754617513

# %% [markdown]
# Bagging Regressor is giving me 78.98% r2_score.

# %% [markdown]
# By looking into the model r2_score and error i found **ExtraTreesRegressor** as the best model with highest r2_score and least errors.

# %% [markdown]
# # Hyper Parameter Tuning:

# %%
#importing necessary libraries
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'max_features':['auto','sqrt','log2'],
             'min_samples_split':[1,2,3,4],
             'n_estimators':[20,40,60,80,100],
             'min_samples_leaf':[1,2,3,4,5],
              'n_jobs':[-2,-1,1,2]}

# %% [markdown]
# Giving ETR parameters.

# %%
GCV=GridSearchCV(ExtraTreesRegressor(),parameter,cv=5)

# %% [markdown]
# Running grid search CV for ETR.

# %%
GCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'min_samples_split': [1, 2, 3, 4],
#                          'n_estimators': [20, 40, 60, 80, 100],
#                          'n_jobs': [-2, -1, 1, 2]})

# %% [markdown]
# Tunning the model using GCV.

# %%
GCV.best_params_
# Out:
# {'max_features': 'auto',
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 80,
#  'n_jobs': 1}

# %% [markdown]
# Got the best parameters for ETR.

# %%
Best_mod=ExtraTreesRegressor(max_features='auto',min_samples_leaf=2,min_samples_split=2,n_estimators=80,n_jobs=1)
Best_mod.fit(X_train,y_train)
pred=Best_mod.predict(X_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# R2_Score: 82.01424634259344
# mean_squared_error: 1119380.6081810314
# mean_absolute_error: 550.2649657480705
# RMSE value: 1058.0078488277068

# %% [markdown]
# This is my model after tuning.I got 82.01% as r2_score before it was 81.18% which means accuracy has increased which is gooddd!!!.

# %% [markdown]
# # Saving the model:

# %%
# Saving the model using .pkl
import joblib
joblib.dump(Best_mod,"Flight_Price.pkl")
# Out:
# ['Flight_Price.pkl']

# %% [markdown]
# I have saved my model as Flight_Price.Using .pkl

# %% [markdown]
# # Predicting Flight Price for test dataset using Saved model of trained dataset:

# %%
# Loading the saved model
model=joblib.load("Flight_Price.pkl")

#Prediction
prediction = model.predict(X_test)
prediction
# Out:
# array([7103.75875   , 7220.78854167, 5102.40416667, ..., 5921.47083333,
#        5940.91875   , 7698.17083333])

# %%
pd.DataFrame([model.predict(X_test)[:],y_test[:]],index=["Predicted","Actual"])
# Out:
#                  0            1            2            3            4     \
# Predicted  7103.75875  7220.788542  5102.404167  6034.927917  8315.571875
# Actual     7671.00000  5566.000000  5061.000000  5900.000000  7425.000000
#
#                  5            6            7            8           9     ...  \
# Predicted  5057.31875  4718.034375  8345.773958  7916.926042  6082.25625  ...
# Actual     5060.00000  4264.000000  8265.000000  7487.000000  5955.00000  ...
#
#                   1551         1552          1553         1554         1555  \
# Predicted  5256.193333  5416.614167   9712.164583  7882.059375  5269.427083
# Actual     4845.000000  5109.000000  12089.000000  7626.000000  5178.000000
#
#                   1556         1557         1558        1559         1560
# Predicted  8296.202292  6029.782292  5921.470833  5940.91875  7698.170833
# Actual     6018.000000  5937.000000  5941.000000  5954.00000  7626.000000
#
# [2 rows x 1561 columns]

# %% [markdown]
# Above are the predicted values and the actual values.They are almost similar.

# %%
plt.figure(figsize=(10,5))
plt.scatter(y_test, prediction, c='crimson')
p1 = max(max(prediction), max(y_test))
p2 = min(min(prediction), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Actual', fontsize=15)
plt.ylabel('Predicted', fontsize=15)
plt.title("ExtraTreesRegressor")
plt.show()

# %% [markdown]
# Plotting Actual vs Predicted,To get better insight.Bule line is the actual line and red dots are the predicted values.
