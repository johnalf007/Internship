# %% [markdown]
# # WEB SCRAPING-ASSIGNMENT 3

# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
#installing required liberaries 
# !pip install selenium
import selenium
import pandas as pd

#importing selenium webdriver
from selenium import webdriver 

#importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

import warnings
warnings.filterwarnings('ignore')
import time

#importing requestrs
import requests

#importing regex
import re

# %%
#extracting path of the webdriver
driver= webdriver.Chrome(r"C:\Users\Asus\Desktop\webdriver\chromedriver.exe")

driver=webdriver.Chrome("chromedriver.exe")
time.sleep(2)

#fetching the url
driver.get("https://www.amazon.in/")

# %%
#Searching for the products by entering the product name
search_feild_product_name=driver.find_element_by_class_name('nav-input')
search_feild_product_name.send_keys('Guitars')

#to display the results for guitars in amazon
search_button=driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search_button.click()

# %% [markdown]
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
#creating an empty list to scrap all brand names in the first page
brand_names=[]
#scrapting all the tags brand names
brand=driver.find_elements_by_class_name("a-size-medium")

#displaying all the brand names in text
for i in brand:
    brands=i.text
    brand_names.append(brands)
brand_names
# Out:
# ['The Ultimate Microphones for Streamers & Creators',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (natural)',
#  'Vault Traveller 34 Inch Acoustic Guitar With Bag, Strap, Strings, Polishing Cloth, String Winder and Picks - Natural Gloss',
#  'Blueberry 38C, 38" Acoustic Guitar Kit with Bag, Strap, One Pack Strings And Picks (Black)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juarez Acoustic Guitar Kit, 38 Inch Cutaway, 38C with Bag, Strings, Pick and Strap, TBS Transparent Blue Sunburst',
# ...

# %%
#to display the results guitars in page 2
next_page=driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[66]/div/div/span/a[3]')
next_page.click()

# %%
#creating an empty list to scrap all brand names in the second page
brand_names2=[]
#scrapting all the tags brand names
brand2=driver.find_elements_by_class_name("a-size-mini")

#displaying all the brand names in text
for i in brand2:
    brands2=i.text
    brand_names2.append(brands2)
brand_names2
# Out:
# ['Vault Traveller 34 Inch Acoustic Guitar With Bag, Strap, Strings, Polishing Cloth, String Winder and Picks - Natural Gloss',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Blueberry B40L, 40" Acoustic Guitar Kit Inbuilt Truss Rod with Bag, Strap, One Pack Strings And Picks (Classic Brown)',
#  'Cort AD810 Dreadnought Acoustic Guitar with Gig Bag,Tuner,Picks and Strap (Natural Bundle)',
#  'Intern INT-38C Natural Acoustic Guitar kit with carry bag & picks',
#  'Saga SF-600GC Grand Concert Acoustic Guitar',
#  '₹8,499\n₹8,990',
#  'Kadence Frontier Series,Black Acoustic Guitar With Die Cast Keys Combo (Bag,strap,strings and 3 picks)',
#  'Kadence Guitar Acoustica Series, Electric Acoustic Guitar, Ash Wood with Pickup and Inbuilt tuner (Ash Wood, Electro Acoustic)',
#  'YAMAHA FS80C NATURAL CONCERT CUTAWAY GUITAR',
# ...

# %%
#To display the results for guitars in page 3
next_page2=driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[65]/div/div/span/a[4]')
next_page2.click()

# %%
#creating an empty list to scrap all brand names in the third page
brand_names3=[]
#scrapting all the tags brand names
brand3=driver.find_elements_by_class_name("a-size-mini")

#displaying all the brand names in text
for i in brand3:
    brands3=i.text
    brand_names3.append(brands3)
brand_names3
# Out:
# ['Blueberry B40L, 40" Acoustic Guitar Kit Inbuilt Truss Rod with Bag, Strap, One Pack Strings And Picks (Classic Maroon)',
#  '₹4,295\n₹10,990',
#  'Blueberry D38 TrussRod Acoustic Guitar Kit with Bag, String,Belt & Picks (Sunburst)',
#  'Cort AD810-OP Acoustic Guitar, Brown',
#  'Givson Venus Special Cutaway Rosewood 41 Inch Acoustic Guitar Kit with Bag, Rhythm String Set, Strap and 5 Plectrums, (Red)',
#  'Ibanez RG Gio Series GRGR221PA Electric Guitar- Aqua Burst',
#  'Kadence Guitar Acoustica Series, Electric Acoustic Guitar, Ash Wood with Pickup and Inbuilt tuner (Ash Wood, Electro Acoustic)',
#  'Fender Squier MM Stratocaster Electric Guitar - Red with Maple Neck',
#  'GIUSON MED-BLACK-GS Acoustic Guitar',
#  'Kadence Frontier Series, Semi Acoustic Guitar With Die Cast Keys (Bag,Strap,Strings And 3 Picks) (Brown)',
#  'Yamaha FSX80C Semi Acoustic Cutaway Guitar with Bag (Black)',
# ...

# %%
#fetching URL to open each product
product_url=[]

#scrapting all the products with URL
url=driver.find_elements_by_xpath("//a[@class='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")

#retreiving URL we use get_attribute
for i in url:
    product_url.append(i.get_attribute('href'))
product_url
# Out:
# ['https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A09610753VGW0EUUEOMBV&url=%2FPremium-Spruce-Top-Cutaway-Acoustic-Guitar%2Fdp%2FB08FFZY6BJ%2Fref%3Dsr_1_1_sspa%3Fcrid%3D3L86EXPZQJGTL%26keywords%3DGuitars%26qid%3D1653584368%26sprefix%3D%252Caps%252C680%26sr%3D8-1-spons%26psc%3D1&qualifier=1653584368&id=1920119336939428&widgetName=sp_atf',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A00573293MJIKRIM2JX20&url=%2FBlueberry-38C-Acoustic-Strings-Sunburst%2Fdp%2FB08KLMQN88%2Fref%3Dsr_1_2_sspa%3Fcrid%3D3L86EXPZQJGTL%26keywords%3DGuitars%26qid%3D1653584368%26sprefix%3D%252Caps%252C680%26sr%3D8-2-spons%26psc%3D1&qualifier=1653584368&id=1920119336939428&widgetName=sp_atf',
# ...

# %%
#to display the results guitars in page 2
next_page=driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[61]/div/div/span/a[3]')
next_page.click()

# %%
#fetching URL to open each product in page 2 
product_url2=[]

#scrapting all the products with URL
url2=driver.find_elements_by_xpath("//a[@class='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")

#retreiving URL we use get_attribute
for i in url2:
    product_url2.append(i.get_attribute('href'))
product_url2
# Out:
# ['https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg2_1?ie=UTF8&adId=A0678391WRHYPDYJEURE&url=%2FTraveller-Acoustic-Guitar-Strings-Polishing%2Fdp%2FB07RK9962M%2Fref%3Dsr_1_49_sspa%3Fcrid%3D3L86EXPZQJGTL%26keywords%3DGuitars%26qid%3D1653585892%26sprefix%3D%252Caps%252C680%26sr%3D8-49-spons%26psc%3D1&qualifier=1653585892&id=2496659465992895&widgetName=sp_atf_next',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg2_1?ie=UTF8&adId=A061107531TUGN5RHMV0N&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB01GDZ46AA%2Fref%3Dsr_1_50_sspa%3Fcrid%3D3L86EXPZQJGTL%26keywords%3DGuitars%26qid%3D1653585892%26smid%3DAM04Z7MH4HSDD%26sprefix%3D%252Caps%252C680%26sr%3D8-50-spons%26psc%3D1%26smid%3DAM04Z7MH4HSDD&qualifier=1653585892&id=2496659465992895&widgetName=sp_atf_next',
# ...

# %%
#to display the results guitars in page 3
next_page2=driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[65]/div/div/span/a[4]')
next_page2.click()

# %%
#fetching URL to open each product in page 3
product_url3=[]

#scrapting all the products with URL
url3=driver.find_elements_by_xpath("//a[@class='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")

#retreiving URL we use get_attribute
for i in url3:
    product_url3.append(i.get_attribute('href'))
product_url3
# Out:
# ['https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg3_1?ie=UTF8&adId=A07400101YBINYLP9UEXI&url=%2FPremium-Spruce-Top-Cutaway-Acoustic-Guitar%2Fdp%2FB08FFZY6BJ%2Fref%3Dsr_1_97_sspa%3Fcrid%3D3L86EXPZQJGTL%26keywords%3DGuitars%26qid%3D1653586063%26sprefix%3D%252Caps%252C680%26sr%3D8-97-spons%26psc%3D1&qualifier=1653586063&id=5664040729324545&widgetName=sp_atf_next',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg3_1?ie=UTF8&adId=A00514452JKYA7IP4JEAA&url=%2FBlueberry-Acoustic-Inbuilt-Strings-Classic%2Fdp%2FB09VLF8B8G%2Fref%3Dsr_1_98_sspa%3Fcrid%3D3L86EXPZQJGTL%26keywords%3DGuitars%26qid%3D1653586063%26sprefix%3D%252Caps%252C680%26sr%3D8-98-spons%26psc%3D1&qualifier=1653586063&id=5664040729324545&widgetName=sp_atf_next',
# ...

# %%
#creating an empty list to scrap all prices in page 1
product_price=[]
#scrapting all products having price
price=driver.find_elements_by_class_name("a-price-whole")

#displaying the data into text
for i in price:
    prce=i.text
    product_price.append(prce)
product_price
# Out:
# ['3,595',
#  '8,995',
#  '10,807',
#  '2,695',
#  '2,095',
#  '2,150',
#  '2,639',
#  '7,499',
#  '2,150',
#  '5,399',
#  '',
#  '',
#  '5,499',
#  '2,639',
#  '2,639',
#  '4,280',
#  '5,399',
#  '1,990',
#  '2,639',
#  '2,639',
#  '2,090',
#  '2,599',
#  '2,290',
#  '2,199',
#  '7,349',
#  '4,295',
#  '2,199',
#  '3,169',
#  '8,990',
#  '3,599',
#  '2,499',
#  '7,499',
#  '3,890',
#  '2,350',
#  '2,090',
#  '2,499',
#  '8,160',
#  '2,290',
#  '19,029',
#  '1,549',
#  '51,138',
#  '181',
#  '9,990',
#  '7,500',
#  '5,759',
#  '9,999',
#  '5,248',
#  '2,799',
#  '6,890',
#  '2,649',
#  '2,290',
#  '7,348',
#  '2,290',
#  '14,900',
#  '3,999',
#  '4,280',
#  '2,390',
#  '2,090']

# %%
#to display the results in next page
next_page4=driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[56]/div/div/span/a[3]')
next_page4.click()

# %%
#creating an empty list to scrap all prices in page 2
product_price2=[]
#scrapting all products having price
price2=driver.find_elements_by_class_name("a-price-whole")

#displaying the data into text
for i in price2:
    prce2=i.text
    product_price2.append(prce2)
product_price2
# Out:
# ['3,999',
#  '5,399',
#  '4,295',
#  '10,150',
#  '4,999',
#  '8,999',
#  '7,499',
#  '2,499',
#  '8,499',
#  '2,695',
#  '8,499',
#  '2,639',
#  '6,649',
#  '2,649',
#  '2,250',
#  '25,384',
#  '9,899',
#  '2,290',
#  '4,280',
#  '2,479',
#  '3,990',
#  '2,695',
#  '6,499',
#  '2,795',
#  '9,379',
#  '7,499',
#  '5,739',
#  '2,250',
#  '2,500',
#  '6,014',
#  '3,499',
#  '2,499',
#  '249',
#  '2,090',
#  '11,040',
#  '2,695',
#  '4,999',
#  '299',
#  '10,150',
#  '5,984',
#  '9,990',
#  '6,478',
#  '12,899',
#  '8,499',
#  '4,789',
#  '22,523',
#  '8,999',
#  '4,295',
#  '4,199',
#  '6,823',
#  '486',
#  '2,639',
#  '2,589',
#  '5,799',
#  '8,667',
#  '7,348',
#  '2,695',
#  '4,190']

# %%
#to display the results in next page
next_page5=driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[64]/div/div/span/a[4]')
next_page5.click()

# %%
#creating an empty list to scrap all prices in page 3
product_price3=[]
#scrapting all products having price
price3=driver.find_elements_by_class_name("a-price-whole")

#displaying the data into text
for i in price3:
    prce3=i.text
    product_price3.append(prce3)
product_price3
# Out:
# ['3,595',
#  '8,995',
#  '10,807',
#  '6,890',
#  '4,295',
#  '7,499',
#  '6,499',
#  '3,999',
#  '24,624',
#  '8,999',
#  '7,499',
#  '2,500',
#  '5,999',
#  '13,680',
#  '2,590',
#  '6,719',
#  '699',
#  '14,990',
#  '3,490',
#  '8,995',
#  '12,880',
#  '2,695',
#  '7,990',
#  '2,895',
#  '4,999',
#  '3,695',
#  '6,500',
#  '5,499',
#  '6,999',
#  '2,390',
#  '789',
#  '4,199',
#  '186',
#  '9,999',
#  '2,290',
#  '7,590',
#  '2,795',
#  '499',
#  '3,999',
#  '5,199',
#  '239',
#  '4,280',
#  '4,190',
#  '3,999',
#  '9,995',
#  '2,895',
#  '5,832',
#  '975',
#  '8,570',
#  '20,158',
#  '2,589',
#  '3,990',
#  '3,949',
#  '6,033',
#  '5,969',
#  '13,290',
#  '2,795',
#  '9,490',
#  '6,719']

# %%
#creating an empty list to scrap all delivery dates in page 1
expected_delivery=[]
#scrapting all products having dates
delivery=driver.find_elements_by_class_name('a-row')

#displaying the data into text
for i in delivery:
    deli=i.text
    expected_delivery.append(deli)
expected_delivery
# Out:
# ['Sponsored',
#  '',
#  '9',
#  '₹2,695\n₹6,995 (61% off)',
#  'Get it by Friday, June 3\nFREE Delivery by Amazon',
#  'Get it by Friday, June 3',
#  'FREE Delivery by Amazon',
#  'Best seller',
#  '15,901',
#  '₹2,095\n₹6,990 (70% off)',
#  'Get it by Sunday, May 29\nFREE Delivery by Amazon',
#  'Get it by Sunday, May 29',
#  'FREE Delivery by Amazon',
#  '10,059',
#  '₹2,150\n₹6,495 (67% off)',
#  'Get it Saturday, May 28 - Tuesday, May 31',
#  "Amazon's Choice",
#  '5,283',
#  '₹2,639\n₹6,990 (62% off)',
#  'Get it by Tuesday, May 31\nFREE Delivery by Amazon',
#  'Get it by Tuesday, May 31',
#  'FREE Delivery by Amazon',
#  '1,033',
#  'Limited time deal',
#  '₹7,499\n₹9,900 (24% off)',
#  'Get it by Saturday, May 28\nFREE Delivery by Amazon',
#  'Get it by Saturday, May 28',
#  'FREE Delivery by Amazon',
# ...

# %%
#to display the results in next page
next_page6=driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[56]/div/div/span/a[3]')
next_page6.click()

# %%
#creating an empty list to scrap all delivery dates in page 2
expected_delivery2=[]
#scrapting all products having dates
delivery2=driver.find_elements_by_class_name('a-color-base')

#displaying the data into text
for i in delivery2:
    deli2=i.text
    expected_delivery2.append(deli2)
expected_delivery2
# Out:
# ['Best Acoustic Guitars',
#  '₹7,499\n00\n₹8,800.00\n(15% off)',
#  '₹7,499\n00\n₹10,600.00\n(29% off)',
#  '',
#  'RESULTS',
#  '',
#  'Vault Traveller 34 Inch Acoustic Guitar With Bag, Strap, Strings, Polishing Cloth, String Winder and Picks - Natural Gloss',
#  'Vault Traveller 34 Inch Acoustic Guitar With Bag, Strap, Strings, Polishing Cloth, String Winder and Picks - Natural Gloss',
#  '₹3,999\n₹9,600 (58% off)',
#  'Get it by',
#  'Tuesday, May 31',
#  'FREE Delivery by Amazon',
#  '',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  '₹5,399\n₹6,050 (11% off)',
#  'Get it by',
#  'Saturday, May 28',
#  'FREE Delivery by Amazon',
#  '',
# ...

# %%
#to display the results in next page
next_page7=driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[64]/div/div/span/a[4]')
next_page7.click()

# %%
#creating an empty list to scrap all delivery dates in page 3
expected_delivery3=[]
#scrapting all products having dates
delivery3=driver.find_elements_by_class_name('a-color-base')

#displaying the data into text
for i in delivery3:
    deli3=i.text
    expected_delivery3.append(deli3)
expected_delivery3
# Out:
# ["There's nothing like playing a genuine Henrix",
#  'Henrix PRO 38 Inch 6 String Cutaway Acoustic Guitar With Die Cast Tuners, Gi…',
#  'RESULTS',
#  '',
#  'Vault EA40 41 inch Premium Solid Spruce-Top Cutaway Acoustic Guitar',
#  'Vault EA40 41 inch Premium Solid Spruce-Top Cutaway Acoustic Guitar',
#  '₹6,890\n₹17,800 (61% off)',
#  'Get it by',
#  'Saturday, May 28',
#  'FREE Delivery by Amazon',
#  '',
#  'Blueberry B40L, 40" Acoustic Guitar Kit Inbuilt Truss Rod with Bag, Strap, One Pack Strings And Picks (Classic Maroon)',
#  'Blueberry B40L, 40" Acoustic Guitar Kit Inbuilt Truss Rod with Bag, Strap, One Pack Strings And Picks (Classic Maroon)',
#  '₹4,295\n₹10,990 (61% off)',
#  'Get it by',
#  'Friday, June 3',
#  'FREE Delivery by Amazon',
#  '',
#  'Kadence Guitar Acoustica Series, 41” Jumbo Size 6-strings Acoustic Guitar, Spruce body with Pick Guard A311 with bag',
# ...

# %% [markdown]
# # 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(2)

#fetching the url for access the webpage
driver.get("https://images.google.com/")

# %%
#Searching for images with xpath
search_feild_product_name=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_feild_product_name.send_keys('Fruits')

#to display the images for fruits in google
search_button1=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
search_button1.click()

# %%
#getting images from website
for _ in range(20):
    driver.execute_script("window.scrollBy(0,100)")
    
images=driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls=[]
img_data=[]
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
#downloading the images
for i in range(len(img_urls)):
    if i >10:
        break
    print("Downloading {0} for {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Asus\Downloads\KG"+str(i)+"jpg","wb")
    file.write(response.content)

# %%
#Searching for images with xpath
search_feild_product_name=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_feild_product_name.send_keys('Cakes')

#to display the images for cakes in google
search_button2=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
search_button2.click()



#getting images from website
for _ in range(20):
    driver.execute_script("window.scrollBy(0,100)")
    
images=driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls=[]
img_data=[]
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
#downloading the images
for i in range(len(img_urls)):
    if i >10:
        break
    print("Downloading {0} for {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Asus\Downloads\KG"+str(i)+"jpg","wb")
    file.write(response.content)

# %%
#Searching for images with xpath
search_feild_product_name=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_feild_product_name.send_keys('Guitars')

#to display the images for guitars in google
search_button3=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
search_button3.click()



#getting images from website
for _ in range(20):
    driver.execute_script("window.scrollBy(0,100)")
    
images=driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls=[]
img_data=[]
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
#downloading the images
for i in range(len(img_urls)):
    if i >10:
        break
    print("Downloading {0} for {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Asus\Downloads\KG"+str(i)+"jpg","wb")
    file.write(response.content)

# %%
#Searching for images with xpath
search_feild_product_name=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_feild_product_name.send_keys('Cars')

#to display the images for cars in google
search_button4=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
search_button4.click()



#getting images from website
for _ in range(20):
    driver.execute_script("window.scrollBy(0,100)")
    
images=driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls=[]
img_data=[]
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
#downloading the images
for i in range(len(img_urls)):
    if i >10:
        break
    print("Downloading {0} for {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Asus\Downloads\KG"+str(i)+"jpg","wb")
    file.write(response.content)

# %%
#Searching for images with xpath
search_feild_product_name=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_feild_product_name.send_keys('Machine learning')

#to display the images for machine learning in google
search_button5=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
search_button5.click()



#getting images from website
for _ in range(20):
    driver.execute_script("window.scrollBy(0,100)")
    
images=driver.find_elements_by_xpath('//img[@class=class="rg_i Q4LuWd"]')

img_urls=[]
img_data=[]
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
#downloading the images
for i in range(len(img_urls)):
    if i >10:
        break
    print("Downloading {0} for {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Asus\Downloads\KG"+str(i)+"jpg","wb")
    file.write(response.content)

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be  scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,  “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(2)

#fetching the url of the webpage
driver.get("https://images.google.com/")

# %%
#Searching for google maps
search_feild_name=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_feild_name.send_keys('Google Maps')

#Clicking on next to search on google
search_button6=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
search_button6.click()

# %%
#Clicking on google maps
press_button=driver.find_element_by_xpath('/html/body/div[7]/div/div[10]/div/div[2]/div[2]/div/div/div[2]/div/div/div[1]/div/a/h3')
press_button.click()

# %%
#searching for Mumbai in google maps search bar
search_feild_name=driver.find_element_by_xpath('/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div[2]/div[3]/div/input[1]')
search_feild_name.send_keys('Mumbai')

#clicking on search to find city
click_button7=driver.find_element_by_xpath('/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]')
click_button7.click()

# %%
url_string=driver.current_url
print("https://www.google.co.in/maps/place/Mumbai,+Maharashtra/@19.0825223,72.7410994,11z/data=!3m1!4b1!4m5!3m4!1s0x3be7c6306644edc1:0x5da4ed8f8d648c69!8m2!3d19.0759837!4d72.8776559", url_string)
# Out:
# https://www.google.co.in/maps/place/Mumbai,+Maharashtra/@19.0825223,72.7410994,11z/data=!3m1!4b1!4m5!3m4!1s0x3be7c6306644edc1:0x5da4ed8f8d648c69!8m2!3d19.0759837!4d72.8776559 https://www.google.co.in/maps/place/Mumbai,+Maharashtra/@19.0825223,72.7410994,11z/data=!3m1!4b1!4m5!3m4!1s0x3be7c6306644edc1:0x5da4ed8f8d648c69!8m2!3d19.0759837!4d72.8776559
